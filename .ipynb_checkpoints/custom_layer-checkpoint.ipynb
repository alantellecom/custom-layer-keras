# %% [markdown]
# # Custom Layers in Keras

# %% [markdown]
# # Task 1: Importing Libraries

# %%
import tensorflow as tf
import utils
import matplotlib.pyplot as plt
# %matplotlib inline

print('TensorFlow Version:', tf.__version__)
# Out:
# TensorFlow Version: 2.1.0

# %% [markdown]
# # Task 2: Import and Visualize Dataset

# %%
(x_train, y_train), (x_test, y_test)= utils.load_data()
utils.plot_random_examples(x_train, y_train).show()

# %% [markdown]
# # Task 3: Creating a Custom Layer

# %%
class ParametricRelu(tf.keras.layers.Layer):
    def __init__(self,**kwargs):
        #super(ParametricRelu, self).__init__(**kwargs)
        super().__init__(**kwargs)
    def build(self, input_shape):
        self.alpha = self.add_weight(name= 'alpha', shape=(1,), initializer='zeros',trainable=True)
        super(ParametricRelu, self).build(input_shape)
    def call(self, x):
        return tf.maximum(0.,x) + self.alpha * tf.minimum(0., x)

# %% [markdown]
# # Task 4: Creating the Model

# %%
def create_model(use_prelu=True):
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(64, input_shape=(784,)))
    if use_prelu:
        model.add(ParametricRelu())
    else:
        model.add(tf.keras.layers.ReLU())
    model.add(tf.keras.layers.Dense(10, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                50240
# _________________________________________________________________
# parametric_relu (ParametricR (None, 64)                1
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 50,891
# Trainable params: 50,891
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Task 5: Model Training

# %%
print('Inital alpha', model.layers[1].get_weights())

h= model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=5 )
# Out:
# Inital alpha [array([0.], dtype=float32)]
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 7s 108us/sample - loss: 0.2961 - accuracy: 0.9171 - val_loss: 0.1588 - val_accuracy: 0.9527
# Epoch 2/5
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.1284 - accuracy: 0.9620 - val_loss: 0.1144 - val_accuracy: 0.9640
# Epoch 3/5
# 60000/60000 [==============================] - 6s 97us/sample - loss: 0.0902 - accuracy: 0.9728 - val_loss: 0.0952 - val_accuracy: 0.9707
# Epoch 4/5
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.0701 - accuracy: 0.9790 - val_loss: 0.0937 - val_accuracy: 0.9732
# Epoch 5/5
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.0569 - accuracy: 0.9823 - val_loss: 0.0968 - val_accuracy: 0.9728

# %%
print ('Final alpha', model.layers[1].get_weights())
# Out:
# Final alpha [array([-0.9029136], dtype=float32)]

# %%
utils.plot_results(h).show()

# %% [markdown]
# # Task 6: Comparison with ReLU

# %%
model = create_model(use_prelu=False)
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 64)                50240
# _________________________________________________________________
# re_lu (ReLU)                 (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                650
# =================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
h= model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=5 )
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.3070 - accuracy: 0.9132 - val_loss: 0.1749 - val_accuracy: 0.9477
# Epoch 2/5
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.1476 - accuracy: 0.9574 - val_loss: 0.1230 - val_accuracy: 0.9629
# Epoch 3/5
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.1055 - accuracy: 0.9691 - val_loss: 0.1046 - val_accuracy: 0.9676
# Epoch 4/5
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.0830 - accuracy: 0.9753 - val_loss: 0.0964 - val_accuracy: 0.9706
# Epoch 5/5
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.0688 - accuracy: 0.9793 - val_loss: 0.0886 - val_accuracy: 0.9711

# %%
utils.plot_results(h).show()
